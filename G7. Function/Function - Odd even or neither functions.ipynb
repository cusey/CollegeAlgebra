# %%
import pylab
import math
import numpy as np

# %% [markdown]
# # Function - Odd even or neither functions

# %% [markdown]
# ## Even Function

# %%
x = np.linspace(-2, 2, 100)  # 100 evenly-spaced values from -2 to 2 
y = x**2+1

pylab.plot(x, y)
pylab.show()

# %% [markdown]
# ## Odd Function
